# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0,'/home/yunye/tools/gwaslab_dev/src')
import gwaslab as gl

# %%
sumstats=pd.read_table("/home/yunye/mydata/AF_bbj.txt.gz",sep="\s+")

# %%
sumstats=sumstats.loc[sumstats["POS"]%5==1,:]

# %% [markdown]
# # Manhattan plot

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE")
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Skip annotating
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20)
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 10...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Skip annotating
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20,cutfactor=50)
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 50...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Skip annotating
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20,cutfactor=50,anno=True,colors=["purple","red"])
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 50...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Annotating using column CHR:POS...
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20,cutfactor=50,anno=True,colors=["green","black","orange"])
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 50...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Annotating using column CHR:POS...
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20,cutfactor=50,anno=True)
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 50...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Annotating using column CHR:POS...
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20,cutfactor=50,anno=False,colors=["purple","red"])
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 50...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Skip annotating
#   - Created Manhattan plot successfully!

# %%
gl.mplot(sumstats,"CHR","POS","PVALUE",cut=20,cutfactor=50,anno="SNP",verbose=True)
# Out:
# Basic settings:
#   - Genome-wide significance level is set to 5e-08 ...
#   - Raw input contains 1004487 variants...
# Strat conversion and QC:
#   - P values are being -log10 scaled...
#   - 0 na/inf/-inf variants will be removed...
#   - Minus log10(P) values will be shrunk at 20 with a shrinkage factor of 50...
# Plotting 1004487 variants...
#   - Found 12 significant variants with a sliding window size of 500 kb...
#   - Annotating using column SNP...
#   - Created Manhattan plot successfully!

# %% [markdown]
# # QQ plot

# %%
gl.qqplot(sumstats,"PVALUE")
# Out:
# Processing 1004487 variants...
# P values are being scaled to -log10(P)...

# %% [markdown]
# # Identified lead SNPs using a sliding window

# %%
gl.getsig(sumstats,"SNP","CHR","POS","PVALUE",500)
# Out:
#   - Processing 1004487 variants...
#   - Found 206 significant variants with a sliding window size of 500 kb...
#   - Identified 12 lead variants!
#                 SNP  CHR        POS A1 A2   FREQ1  CASE_FREQ1  CTRL_FREQ1  \
# 195836   rs12129789    1  112379026  T  A  0.5041      0.4844      0.5077
# 249508     rs539045    1  170608081  C  T  0.5396      0.5730      0.5360
# 308252   rs10920555    1  203027021  G  A  0.7971      0.8219      0.7957
# 526695    rs2540951    2   65276736  A  G  0.6686      0.6921      0.6620
# 1401121  rs72900149    4  111709641  C  A  0.5458      0.4228      0.5532
# 1521141  rs80073944    4  174440356  A  G  0.9174      0.9014      0.9169
# 1810852  rs17118812    5  139703286  T  C  0.6202      0.6062      0.6239
# 2437450   rs3807995    7  116197976  C  T  0.7134      0.7423      0.7119
# 3069262  rs12777530   10   21144981  C  T  0.7906      0.7699      0.7977
# 3222344  rs60469668   10  105331866  A  G  0.9082      0.8767      0.9096
# ...

# %% [markdown]
# # Calculated Genomic inflation factor using p/z/chi2

# %%
gl.gc(sumstats["PVALUE"])
# Out:
# (p mode) Lambda GC at 0.5 is   1.28679
# 1.2867926588058096

# %%
gl.gc(np.sqrt(sumstats["WALDCHISQ"]),mode="z")
# Out:
# (z mode) Lambda GC at 0.5 is   1.28655
# 1.286553395717371

# %% [markdown]
# # Converting observed scale heritability to liability scale heritability
