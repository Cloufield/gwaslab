# %%
# !wget -O bmi_male_bbj.txt.gz http://jenger.riken.jp/2analysisresult_qtl_download/
# !wget -O bmi_female_bbj.txt.gz http://jenger.riken.jp/4analysisresult_qtl_download/
# Out:
# --2022-10-24 13:19:42--  http://jenger.riken.jp/2analysisresult_qtl_download/
# Resolving jenger.riken.jp (jenger.riken.jp)... 134.160.84.25
# Connecting to jenger.riken.jp (jenger.riken.jp)|134.160.84.25|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136657659 (130M) [text/plain]
# Saving to: ‘bmi_male_bbj.txt.gz’
#
# bmi_male_bbj.txt.gz 100%[===================>] 130.33M  15.0MB/s    in 12s
#
# 2022-10-24 13:19:54 (10.9 MB/s) - ‘bmi_male_bbj.txt.gz’ saved [136657659/136657659]
#
# --2022-10-24 13:19:54--  http://jenger.riken.jp/4analysisresult_qtl_download/
# Resolving jenger.riken.jp (jenger.riken.jp)... 134.160.84.25
# Connecting to jenger.riken.jp (jenger.riken.jp)|134.160.84.25|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136645377 (130M) [text/plain]
# Saving to: ‘bmi_female_bbj.txt.gz’
#
# bmi_female_bbj.txt. 100%[===================>] 130.31M  19.6MB/s    in 5.7s
#
# 2022-10-24 13:20:00 (22.7 MB/s) - ‘bmi_female_bbj.txt.gz’ saved [136645377/136645377]

# %%
import sys 
sys.path.insert(0,"/Users/he/work/gwaslab/src")
import gwaslab as gl

# %%
mysumstats = gl.plot_miami(path1="bmi_male_bbj.txt.gz" ,
                           path2="bmi_female_bbj.txt.gz",
                           cols1=["CHR","POS","P"],
                           cols2=["CHR","POS","P"],
                           titles=["bmi male","bmi female"],
                           titles_pad=[0.15,0.0],
                           anno="GENENAME",
                           region_grid=True,
                           highlight1=[(5,124289158)],
                           pinpoint2=[(2,653874)]
                           )
# Out:
# Mon Oct 24 21:13:21 2022 Start to plot miami plot with the following basic settings:
# Mon Oct 24 21:13:21 2022  -Genome-wide significance level is set to 5e-08 ...
# Mon Oct 24 21:13:21 2022  -Loci to highlight :  [] [(5, 124289158)] []
# Mon Oct 24 21:13:21 2022  -Highlight_window is set to:  500  kb
# Mon Oct 24 21:13:21 2022  -Variants to pinpoint :  [] [] [(2, 653874)]
# Mon Oct 24 21:13:21 2022  -Loading sumstats1:bmi_male_bbj.txt.gz
# Mon Oct 24 21:13:21 2022  -Sumstats1 CHR,POS,P information will be obtained from: ['CHR', 'POS', 'P']
# Mon Oct 24 21:13:31 2022  -Loading sumstats2:bmi_female_bbj.txt.gz
# Mon Oct 24 21:13:31 2022  -Sumstats2 CHR,POS,P information will be obtained from: ['CHR', 'POS', 'P']
# Mon Oct 24 21:13:40 2022  - Merging sumstats using chr and pos...
# Mon Oct 24 21:13:57 2022 Plotting...
# Mon Oct 24 21:14:33 2022  -Highlighting target loci for sumstats1...
# Mon Oct 24 21:14:49 2022  -Target vairants to pinpoint were not found. Skip pinpointing process...
# Mon Oct 24 21:15:06 2022  -Pinpointing target vairants...
# Mon Oct 24 21:15:06 2022 Start to annotate variants with nearest gene name(s)...
# Mon Oct 24 21:15:06 2022  -Assigning Gene name using built-in Ensembl Release 75  (hg19)
# Mon Oct 24 21:15:10 2022 Finished annotating variants with nearest gene name(s) successfully!
# Mon Oct 24 21:15:10 2022 Start to annotate variants with nearest gene name(s)...
# Mon Oct 24 21:15:10 2022  -Assigning Gene name using built-in Ensembl Release 75  (hg19)
# Mon Oct 24 21:15:13 2022 Finished annotating variants with nearest gene name(s) successfully!
# Mon Oct 24 21:15:13 2022  -Annotating using column GENENAME...
# Mon Oct 24 21:15:14 2022  -Annotating using column GENENAME...

# %%
mysumstats = gl.plot_miami(path1="bmi_male_bbj.txt.gz" ,
                           path2="bmi_female_bbj.txt.gz",
                           cols1=["CHR","POS","P"],
                           cols2=["CHR","POS","P"],
                           titles=["male","female"],
                           region=(2,2153874,21753874),
                           titles_pad=[0.1,-0.05],
                           readcsv_args={"nrows":100000},
                           anno="GENENAME",
                           region_grid=True
                           )
# Out:
# Mon Oct 24 21:16:02 2022 Start to plot miami plot with the following basic settings:
# Mon Oct 24 21:16:02 2022  -Genome-wide significance level is set to 5e-08 ...
# Mon Oct 24 21:16:02 2022  -Region to plot : chr2:2153874-21753874.
# Mon Oct 24 21:16:02 2022  -Loading sumstats1:bmi_male_bbj.txt.gz
# Mon Oct 24 21:16:02 2022  -Sumstats1 CHR,POS,P information will be obtained from: ['CHR', 'POS', 'P']
# Mon Oct 24 21:16:02 2022  -Loading sumstats2:bmi_female_bbj.txt.gz
# Mon Oct 24 21:16:02 2022  -Sumstats2 CHR,POS,P information will be obtained from: ['CHR', 'POS', 'P']
# Mon Oct 24 21:16:02 2022  - Merging sumstats using chr and pos...
# Mon Oct 24 21:16:03 2022  -Extract SNPs in region : chr2:2153874-21753874...
# Mon Oct 24 21:16:03 2022  -Extract SNPs in specified regions: 1608
# Mon Oct 24 21:16:03 2022 Plotting...
# Mon Oct 24 21:16:03 2022  -Skip annotating
# Mon Oct 24 21:16:03 2022  -Skip annotating
