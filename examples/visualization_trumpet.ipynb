# %%
import sys
sys.path.insert(0,"/home/yunye/work/gwaslab/src")
import gwaslab as gl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as patches
import seaborn as sns
import numpy as np
import scipy as sp
from gwaslab.Log import Log

# %%
mysumstats =gl.Sumstats("t2d_bbj.txt.gz",
             snpid="SNP",
             chrom="CHR",
             pos="POS",
             ea="ALT",
             nea="REF",
             neaf="Frq",
             beta="BETA",
             p="P",
             n="N",
             se="SE",nrows=500000)
# Out:
# Fri Jun 23 01:55:08 2023 GWASLab version 3.4.15 https://cloufield.github.io/gwaslab/
# Fri Jun 23 01:55:08 2023 (C) 2022-2023, Yunye He, Kamatani Lab, MIT License, gwaslab@gmail.com
# Fri Jun 23 01:55:08 2023 Start to initiate from file :t2d_bbj.txt.gz
# Fri Jun 23 01:55:08 2023  -Reading columns          : P,ALT,N,Frq,POS,SNP,REF,BETA,SE,CHR
# Fri Jun 23 01:55:08 2023  -Renaming columns to      : P,EA,N,EAF,POS,SNPID,NEA,BETA,SE,CHR
# Fri Jun 23 01:55:08 2023  -Current Dataframe shape : 500000  x  10
# Fri Jun 23 01:55:08 2023  -Initiating a status column: STATUS ...
# Fri Jun 23 01:55:09 2023  -NEAF is specified...
# Fri Jun 23 01:55:09 2023  -Checking if 0<= NEAF <=1 ...
# Fri Jun 23 01:55:09 2023  -Converted NEAF to EAF.
# Fri Jun 23 01:55:09 2023  -Removed 0 variants with bad NEAF.
# Fri Jun 23 01:55:09 2023 Start to reorder the columns...
# Fri Jun 23 01:55:09 2023  -Current Dataframe shape : 500000  x  11
# Fri Jun 23 01:55:09 2023  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,BETA,SE,P,N,STATUS
# Fri Jun 23 01:55:09 2023 Finished sorting columns successfully!
# Fri Jun 23 01:55:09 2023 Finished loading data successfully!

# %%
a = mysumstats.plot_trumpet(mode="b",
                            scase=20000,
                            scontrol=160000,
                            ts=[0.3,0.5,0.8,0.9] ,
                            sig_level=1e-3,
                            p_level=1e-3,
                            n_matrix=2000,fontsize=20,
                            cmap="cool",
                            markercolor="#349beb")
# Out:
# Fri Jun 23 01:55:09 2023 Start to create trumpet plot...
# Fri Jun 23 01:55:09 2023 Excluding variants with P values > 0.001
# Fri Jun 23 01:55:09 2023 Plotting 3034 variants...
# Fri Jun 23 01:55:09 2023 Start filling data using existing columns...
# Fri Jun 23 01:55:09 2023  -Raw input columns:  ['BETA', 'EAF', 'N', 'P']
# Fri Jun 23 01:55:09 2023  -Overwrite mode:  False
# Fri Jun 23 01:55:09 2023   -Skipping columns:  []
# Fri Jun 23 01:55:09 2023  -Filling columns:  ['MAF']
# Fri Jun 23 01:55:09 2023   - Filling Columns iteratively...
# Fri Jun 23 01:55:09 2023   - Filling MAF using EAF column...
# Fri Jun 23 01:55:09 2023 Start to reorder the columns...
# Fri Jun 23 01:55:09 2023  -Current Dataframe shape : 3034  x  5
# Fri Jun 23 01:55:09 2023  -Reordering columns to    : EAF,MAF,BETA,P,N
# Fri Jun 23 01:55:09 2023 Finished sorting columns successfully!
# Fri Jun 23 01:55:09 2023 Finished filling data using existing columns.
# Fri Jun 23 01:55:09 2023  -Updating eaf-beta matrix...
# Fri Jun 23 01:55:09 2023  -Alogorithm: Skol, Andrew D., et al. Nature genetics 38.2 (2006): 209-213....
# Fri Jun 23 01:55:09 2023  -GRR is approximated using OR. For prevalence < 10%, GRR is very similar to OR....
# Fri Jun 23 01:55:10 2023  -Extracting eaf-beta combinations with power = 0.3...
# Fri Jun 23 01:55:10 2023  -Updating eaf-beta matrix...
# Fri Jun 23 01:55:10 2023  -Alogorithm: Skol, Andrew D., et al. Nature genetics 38.2 (2006): 209-213....
# Fri Jun 23 01:55:10 2023  -GRR is approximated using OR. For prevalence < 10%, GRR is very similar to OR....
# Fri Jun 23 01:55:10 2023  -Extracting eaf-beta combinations with power = 0.5...
# Fri Jun 23 01:55:10 2023  -Updating eaf-beta matrix...
# Fri Jun 23 01:55:10 2023  -Alogorithm: Skol, Andrew D., et al. Nature genetics 38.2 (2006): 209-213....
# Fri Jun 23 01:55:10 2023  -GRR is approximated using OR. For prevalence < 10%, GRR is very similar to OR....
# Fri Jun 23 01:55:11 2023  -Extracting eaf-beta combinations with power = 0.8...
# Fri Jun 23 01:55:11 2023  -Updating eaf-beta matrix...
# Fri Jun 23 01:55:11 2023  -Alogorithm: Skol, Andrew D., et al. Nature genetics 38.2 (2006): 209-213....
# Fri Jun 23 01:55:11 2023  -GRR is approximated using OR. For prevalence < 10%, GRR is very similar to OR....
# Fri Jun 23 01:55:11 2023  -Extracting eaf-beta combinations with power = 0.9...
# Fri Jun 23 01:55:11 2023 Finished creating trumpet plot!
